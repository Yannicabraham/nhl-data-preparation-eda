# %% [markdown]
# ## 🏒📊 Data Cleaning & Preparation | Summary & Descriptive Analyses | Basic Data Visualization
#
# My Data Analysis journey currently takes me on an exciting endeavor to further develop my skills through applied **sports analytics**.
#
# In this notebook, I will use multiple NHL datasets to conduct thorough **data cleaning and preparation**. I will also perform **summary and descriptive analyses** using statistics and visualizations to explore the data's distribution , variable characteristics, and patterns.
#
# Additionally, I will examine relationships between variables using **correlation coefficients**.
#
# **Buckle up and dive deeper into sports analytics with me!** 🤓
#
# ---
# ### 🎓 About the Course
#
# This project was developed as part of the **"Foundations of Sports Analytics"** course offered by the **University of Michigan** on **Coursera**.
# The course introduces key concepts and techniques in sports analytics, focusing on real-world applications using sports data. Topics include data wrangling, summary statistics, data visualization, and interpreting relationships between variables - all applied in the context of sports performance and outcomes.
#
# - 🏫 Insitut: University of Michigan
# - 🌐 Platform: Coursera
# - 📚 Course: Foundations of Sports Analytics
# - 🔗 [Course Link](https://www.coursera.org/learn/foundations-sports-analytics)

# %% [markdown]
# ## Part 1 - Data Coding and Merging

# %%
#Import Libraries
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Import NHL Team Data and Display
NHL_Team=pd.read_csv("Assignment Data/Week 2/NHL_team.csv")
display(NHL_Team)
# Out:
#     Unnamed: 0    tid                   name           tname         lname  \
# 0            1      1    Toronto Maple Leafs     Maple Leafs       Toronto
# 1            2      2     Montréal Canadiens       Canadiens      Montréal
# 2            3      4          Winnipeg Jets            Jets      Winnipeg
# 3            4      5    Washington Capitals        Capitals    Washington
# 4            5      6     Chicago Blackhawks      Blackhawks       Chicago
# 5            6      7        St. Louis Blues           Blues     St. Louis
# 6            7      8    Pittsburgh Penguins        Penguins    Pittsburgh
# 7            8     10        Edmonton Oilers          Oilers      Edmonton
# 8            9     11         Calgary Flames          Flames       Calgary
# 9           10     14    Philadelphia Flyers          Flyers  Philadelphia
# 10          11     16        San Jose Sharks          Sharks      San Jose
# ...

# %%
#Deleting unnecessary rows
NHL_Team.drop(columns=['Unnamed: 0','abbr', 'tname','lname','sname'], axis=1, inplace=True)
display(NHL_Team)
# Out:
#       tid                   name tricode
# 0       1    Toronto Maple Leafs     TOR
# 1       2     Montréal Canadiens     MTL
# 2       4          Winnipeg Jets     WPG
# 3       5    Washington Capitals     WSH
# 4       6     Chicago Blackhawks     CHI
# 5       7        St. Louis Blues     STL
# 6       8    Pittsburgh Penguins     PIT
# 7      10        Edmonton Oilers     EDM
# 8      11         Calgary Flames     CGY
# 9      14    Philadelphia Flyers     PHI
# 10     16        San Jose Sharks     SJS
# 11     17         Buffalo Sabres     BUF
# 12     18      Detroit Red Wings     DET
# 13     19    Nashville Predators     NSH
# 14     20          Boston Bruins     BOS
# 15     21          Anaheim Ducks     ANA
# 16     22     Colorado Avalanche     COL
# 17     25    Tampa Bay Lightning     TBL
# 18     28       New York Rangers     NYR
# 19     29      New Jersey Devils     NJD
# 20     32        Ottawa Senators     OTT
# 21     35         Minnesota Wild     MIN
# ...

# %%
#Renaming for clarity
NHL_Team.rename(columns={'name':'team_name'}, inplace=True)
display(NHL_Team)
# Out:
#       tid              team_name tricode
# 0       1    Toronto Maple Leafs     TOR
# 1       2     Montréal Canadiens     MTL
# 2       4          Winnipeg Jets     WPG
# 3       5    Washington Capitals     WSH
# 4       6     Chicago Blackhawks     CHI
# 5       7        St. Louis Blues     STL
# 6       8    Pittsburgh Penguins     PIT
# 7      10        Edmonton Oilers     EDM
# 8      11         Calgary Flames     CGY
# 9      14    Philadelphia Flyers     PHI
# 10     16        San Jose Sharks     SJS
# 11     17         Buffalo Sabres     BUF
# 12     18      Detroit Red Wings     DET
# 13     19    Nashville Predators     NSH
# 14     20          Boston Bruins     BOS
# 15     21          Anaheim Ducks     ANA
# 16     22     Colorado Avalanche     COL
# 17     25    Tampa Bay Lightning     TBL
# 18     28       New York Rangers     NYR
# 19     29      New Jersey Devils     NJD
# 20     32        Ottawa Senators     OTT
# 21     35         Minnesota Wild     MIN
# ...

# %%
#Import NHL Competition Data and Display Head
NHL_Competition=pd.read_csv("Assignment Data/Week 2/NHL_competition.csv")
NHL_Competition.head()
# Out:
#    Unnamed: 0  comp_id  year  type                     name  tz  start  end
# 0           1        1  2013     2  2013 NHL Regular Season  ET    NaN  NaN
# 1           2        2  2017     2  2017 NHL Regular Season  ET    NaN  NaN
# 2           3     2453  2013     3         2013 NHL Playoff  ET    NaN  NaN
# 3           4     2541  2017     3         2017 NHL Playoff  ET    NaN  NaN
# 4           5     2661  2012     2  2012 NHL Regular Season  ET    NaN  NaN

# %%
#Deleting unwanted columns
NHL_Competition.drop(columns=['Unnamed: 0','tz','start','end'], axis=1,inplace=True)
display(NHL_Competition)
# Out:
#     comp_id  year  type                     name
# 0         1  2013     2  2013 NHL Regular Season
# 1         2  2017     2  2017 NHL Regular Season
# 2      2453  2013     3         2013 NHL Playoff
# 3      2541  2017     3         2017 NHL Playoff
# 4      2661  2012     2  2012 NHL Regular Season
# 5      2734  2016     2  2016 NHL Regular Season
# 6      4099  2012     3         2012 NHL Playoff
# 7      4287  2011     2  2011 NHL Regular Season
# 8      5181  2016     3         2016 NHL Playoff
# 9      5385  2015     2  2015 NHL Regular Season
# 10     5478  2011     3         2011 NHL Playoff
# 11     5662  2010     2  2010 NHL Regular Season
# 12     7813  2015     3         2015 NHL Playoff
# 13     8011  2014     2  2014 NHL Regular Season
# 14     8131  2010     3         2010 NHL Playoff
# 15     9389  2014     3         2014 NHL Playoff

# %%
#Renaming the variable “name” to “competition_name” for clarity again
NHL_Competition.rename(columns={'name':'competition_name'}, inplace=True)
display(NHL_Competition)
# Out:
#     comp_id  year  type         competition_name
# 0         1  2013     2  2013 NHL Regular Season
# 1         2  2017     2  2017 NHL Regular Season
# 2      2453  2013     3         2013 NHL Playoff
# 3      2541  2017     3         2017 NHL Playoff
# 4      2661  2012     2  2012 NHL Regular Season
# 5      2734  2016     2  2016 NHL Regular Season
# 6      4099  2012     3         2012 NHL Playoff
# 7      4287  2011     2  2011 NHL Regular Season
# 8      5181  2016     3         2016 NHL Playoff
# 9      5385  2015     2  2015 NHL Regular Season
# 10     5478  2011     3         2011 NHL Playoff
# 11     5662  2010     2  2010 NHL Regular Season
# 12     7813  2015     3         2015 NHL Playoff
# 13     8011  2014     2  2014 NHL Regular Season
# 14     8131  2010     3         2010 NHL Playoff
# 15     9389  2014     3         2014 NHL Playoff

# %%
#Import NHL Game Data and Display Head
NHL_Game=pd.read_csv("Assignment Data/Week 2/NHL_game.csv")
NHL_Game.head()
# Out:
#    X  gid  comp_id        date  ascore  hscore  period  status home_away  tid
# 0  1   37        2   10/7/2017     NaN     NaN     NaN     NaN      away   25
# 1  2   67        2   10/9/2017     NaN     NaN     NaN     NaN      away   29
# 2  3  154        1  10/14/2013     NaN     NaN     NaN     NaN      away   29
# 3  4  278        1  10/24/2013     NaN     NaN     NaN     NaN      away   53
# 4  5  291        1  10/25/2013     NaN     NaN     NaN     NaN      away    5

# %%
#Deleting the following variables: “X”, “period”, and “status”.
NHL_Game.drop(columns=['X','period','status'], axis=1, inplace=True)
display(NHL_Game)
# Out:
#         gid  comp_id        date  ascore  hscore home_away  tid
# 0        37        2   10/7/2017     NaN     NaN      away   25
# 1        67        2   10/9/2017     NaN     NaN      away   29
# 2       154        1  10/14/2013     NaN     NaN      away   29
# 3       278        1  10/24/2013     NaN     NaN      away   53
# 4       291        1  10/25/2013     NaN     NaN      away    5
# ...     ...      ...         ...     ...     ...       ...  ...
# 18941  4827     4287  11/19/2011     0.0     3.0      home   22
# 18942  7227     5662    2/4/2011     2.0     3.0      home   14
# 18943   790        2   12/2/2017     2.0     1.0      home   45
# 18944  2850     2734  10/21/2016     4.0     2.0      home   11
# 18945  5642     5385  10/29/2015     3.0     1.0      home    5
#
# [18946 rows x 7 columns]

# %%
#Merging the “NHL_Team” df into the “NHL_Game” df by “tid.” Equals updated "NHL_Game" df.
NHL_Game = pd.merge(NHL_Team,NHL_Game, on=['tid'])
display(NHL_Game)
# Out:
#          tid            team_name tricode   gid  comp_id        date  ascore  \
# 0          1  Toronto Maple Leafs     TOR   741        1  11/28/2013     NaN
# 1          1  Toronto Maple Leafs     TOR   782        1   12/1/2013     NaN
# 2          1  Toronto Maple Leafs     TOR  5225     5181   4/25/2017     NaN
# 3          1  Toronto Maple Leafs     TOR  6557     5385    1/7/2016     NaN
# 4          1  Toronto Maple Leafs     TOR  6914     5385    2/7/2016     NaN
# ...      ...                  ...     ...   ...      ...         ...     ...
# 18941  11366    Atlanta Thrashers     ATL  7358     5662   2/13/2011     3.0
# 18942  11366    Atlanta Thrashers     ATL  7786     5662   3/17/2011     3.0
# 18943  11366    Atlanta Thrashers     ATL  7630     5662    3/6/2011     3.0
# 18944  11366    Atlanta Thrashers     ATL  6105     5662  11/12/2010     1.0
# 18945  11366    Atlanta Thrashers     ATL  7229     5662    2/4/2011     4.0
#
#        hscore home_away
# ...

# %%
#Merging df “NHL_Competition” into the df “NHL_Game” by “comp_id.” Equals updated "NHL_Game" df.
NHL_Game = pd.merge(NHL_Competition, NHL_Game, on=['comp_id'])
display(NHL_Game)
# Out:
#        comp_id  year  type         competition_name  tid            team_name  \
# 0            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 1            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 2            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 3            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 4            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# ...        ...   ...   ...                      ...  ...                  ...
# 18941     9389  2014     3         2014 NHL Playoff   53    Vancouver Canucks
# 18942     9389  2014     3         2014 NHL Playoff   53    Vancouver Canucks
# 18943     9389  2014     3         2014 NHL Playoff   53    Vancouver Canucks
# 18944     9389  2014     3         2014 NHL Playoff   53    Vancouver Canucks
# 18945     9389  2014     3         2014 NHL Playoff   53    Vancouver Canucks
#
# ...

# %%
#In the merged “NHL_Game” df, we create the new variable “hgd” to indicate the goal difference between home and away 
#score (hscore – ascore). We then delete observations with missing values in the variable “hgd”.
NHL_Game['hgd'] = NHL_Game['hscore']-NHL_Game['ascore']
NHL_Game=NHL_Game[pd.notna(NHL_Game['hgd'])]
display(NHL_Game)
# Out:
#        comp_id  year  type         competition_name  tid            team_name  \
# 2            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 3            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 4            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 5            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 6            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# ...        ...   ...   ...                      ...  ...                  ...
# 18941     9389  2014     3         2014 NHL Playoff   53    Vancouver Canucks
# 18942     9389  2014     3         2014 NHL Playoff   53    Vancouver Canucks
# 18943     9389  2014     3         2014 NHL Playoff   53    Vancouver Canucks
# 18944     9389  2014     3         2014 NHL Playoff   53    Vancouver Canucks
# 18945     9389  2014     3         2014 NHL Playoff   53    Vancouver Canucks
#
# ...

# %%
#Checking for remaining 0 values in the "NHL_Game" df
NHL_Game.isnull().any()
# Out:
# comp_id             False
# year                False
# type                False
# competition_name    False
# tid                 False
# team_name           False
# tricode             False
# gid                 False
# date                False
# ascore              False
# hscore              False
# home_away           False
# hgd                 False
# dtype: bool

# %%
NHL_Game.shape
# Out:
# (18506, 13)

# %%
#Converting the type of the “date” variable from “object” to “datetime.”
NHL_Game.dtypes
# Out:
# comp_id               int64
# year                  int64
# type                  int64
# competition_name     object
# tid                   int64
# team_name            object
# tricode              object
# gid                   int64
# date                 object
# ascore              float64
# hscore              float64
# home_away            object
# hgd                 float64
# dtype: object

# %%
NHL_Game['date']=pd.to_datetime(NHL_Game['date'])
NHL_Game.head()
# Out:
#    comp_id  year  type         competition_name  tid            team_name  \
# 2        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 3        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 4        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 5        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 6        1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
#
#   tricode   gid       date  ascore  hscore home_away  hgd
# 2     TOR  1003 2013-12-17     1.0     3.0      away  2.0
# 3     TOR  1552 2014-01-26     4.0     5.0      away  1.0
# 4     TOR  1811 2014-03-02     3.0     4.0      away  1.0
# 5     TOR  1940 2014-03-11     3.0     1.0      away -2.0
# 6     TOR  1522 2014-01-24     1.0     7.0      away  6.0

# %%
#Sorting the NHL games by “date” and limiting to the first 15 observations.
NHL_Game.sort_values(by='date').head(15)
# Out:
#        comp_id  year  type         competition_name  tid  \
# 15183     5662  2010     2  2010 NHL Regular Season   35
# 14163     5662  2010     2  2010 NHL Regular Season   14
# 15794     5662  2010     2  2010 NHL Regular Season   66
# 13955     5662  2010     2  2010 NHL Regular Season    8
# 13611     5662  2010     2  2010 NHL Regular Season    2
# 13564     5662  2010     2  2010 NHL Regular Season    1
# 14796     5662  2010     2  2010 NHL Regular Season   22
# 15675     5662  2010     2  2010 NHL Regular Season   52
# 14664     5662  2010     2  2010 NHL Regular Season   21
# 13672     5662  2010     2  2010 NHL Regular Season    5
# 15145     5662  2010     2  2010 NHL Regular Season   35
# 13770     5662  2010     2  2010 NHL Regular Season    6
# 15112     5662  2010     2  2010 NHL Regular Season   32
# 14056     5662  2010     2  2010 NHL Regular Season   10
# 14460     5662  2010     2  2010 NHL Regular Season   18
#
# ...

# %%
#Createíng two dfs that separate the “NHL_Game” dataframe by home and away games. 

NHL_Home = NHL_Game[NHL_Game['home_away'] == 'home']
NHL_Away = NHL_Game[NHL_Game['home_away']== 'away']

# %%
#Renaming variables: 
#For away games: “ascore” to “goals_for”; “hscore” to “goals_against”
#For home games: “hscore” to “goals_for”; “ascore” to “goals_against” 

NHL_Away.rename(columns={'ascore':'goals_for','hscore':'goals_against'},inplace=True)
NHL_Home.rename(columns={'hscore':'goals_for','ascore':'goals_against'},inplace=True)
display(NHL_Away)
# Out:
# /var/folders/0q/s7fj151s553_0czdxm4mtj680000gn/T/ipykernel_65487/371742173.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NHL_Away.rename(columns={'ascore':'goals_for','hscore':'goals_against'},inplace=True)
# /var/folders/0q/s7fj151s553_0czdxm4mtj680000gn/T/ipykernel_65487/371742173.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NHL_Home.rename(columns={'hscore':'goals_for','ascore':'goals_against'},inplace=True)
#        comp_id  year  type         competition_name  tid            team_name  \
# 2            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# ...

# %%
#Creating a new “win” variable that equals to 1 if the team won the game; 0 if the team lost the game; 
#and 0.5 if it was a draw. 

NHL_Away['win'] = np.where(NHL_Away['goals_for'] > NHL_Away['goals_against'], 1, np.where(NHL_Away['hgd'] == 0,0.5,0))
display(NHL_Away)
# Out:
# /var/folders/0q/s7fj151s553_0czdxm4mtj680000gn/T/ipykernel_65487/2930707887.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NHL_Away['win'] = np.where(NHL_Away['goals_for'] > NHL_Away['goals_against'], 1, np.where(NHL_Away['hgd'] == 0,0.5,0))
#        comp_id  year  type         competition_name  tid            team_name  \
# 2            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 3            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 4            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 5            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 6            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# ...

# %%
NHL_Home['win'] = np.where(NHL_Home['goals_for'] > NHL_Home['goals_against'], 1, np.where(NHL_Home['hgd'] == 0,0.5,0))
display(NHL_Home)
# Out:
# /var/folders/0q/s7fj151s553_0czdxm4mtj680000gn/T/ipykernel_65487/1991169300.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   NHL_Home['win'] = np.where(NHL_Home['goals_for'] > NHL_Home['goals_against'], 1, np.where(NHL_Home['hgd'] == 0,0.5,0))
#        comp_id  year  type         competition_name  tid            team_name  \
# 42           1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 43           1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 44           1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 45           1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 46           1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# ...

# %%
#Appending the “NHL_Home” and “NHL_Away” dataframes to be the new “NHL_Game” dataframe using the concat function
NHL_Game = pd.concat([NHL_Home, NHL_Away], axis=0, ignore_index=True)
display(NHL_Game)
# Out:
#        comp_id  year  type         competition_name  tid            team_name  \
# 0            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 1            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 2            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 3            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# 4            1  2013     2  2013 NHL Regular Season    1  Toronto Maple Leafs
# ...        ...   ...   ...                      ...  ...                  ...
# 18501     9389  2014     3         2014 NHL Playoff   51   New York Islanders
# 18502     9389  2014     3         2014 NHL Playoff   51   New York Islanders
# 18503     9389  2014     3         2014 NHL Playoff   53    Vancouver Canucks
# 18504     9389  2014     3         2014 NHL Playoff   53    Vancouver Canucks
# 18505     9389  2014     3         2014 NHL Playoff   53    Vancouver Canucks
#
# ...

# %%
#Generating a team level dataframe that aggregates the total number of games won, the total number of 
#“goals_for” and “goals_against” for each team in each competition (i.e. grouped by tid, competition_name and type)
#Naming this new dataframe “NHL_Team_Stats”. 
#Making sure to convert the indexes of the new dataframe back as  variables. 

NHL_Team_Stats = NHL_Game.groupby(['team_name','tid','competition_name','type'])[['win','goals_for','goals_against']].sum().sort_values(['tid','competition_name']).reset_index()
display(NHL_Team_Stats)
# Out:
#                team_name    tid         competition_name  type   win  \
# 0    Toronto Maple Leafs      1  2010 NHL Regular Season     2  36.0
# 1    Toronto Maple Leafs      1  2011 NHL Regular Season     2  20.0
# 2    Toronto Maple Leafs      1         2012 NHL Playoff     3   3.0
# 3    Toronto Maple Leafs      1  2012 NHL Regular Season     2  25.0
# 4    Toronto Maple Leafs      1  2013 NHL Regular Season     2  38.0
# ..                   ...    ...                      ...   ...   ...
# 364  Carolina Hurricanes     66  2014 NHL Regular Season     2  30.0
# 365  Carolina Hurricanes     66  2015 NHL Regular Season     2  34.0
# 366  Carolina Hurricanes     66  2016 NHL Regular Season     2  35.5
# 367  Carolina Hurricanes     66  2017 NHL Regular Season     2  35.5
# 368    Atlanta Thrashers  11366  2010 NHL Regular Season     2  34.0
#
#      goals_for  goals_against
# 0        223.0          259.0
# 1        129.0          129.0
# 2         18.0           22.0
# ...

# %%
#Creating a dataframe “NHL_Game_Count” that include the total number of games played by each team in each 
#competition (i.e. grouped by tid, competition_name and type). 
#Naming this new variable in the dataframe “game_count”

NHL_Game['game_count'] = 1
NHL_Game_Count = NHL_Game.groupby(['team_name','tid','competition_name','type'])[['game_count']].sum().sort_values(['tid','competition_name']).reset_index()
display(NHL_Game_Count)
# Out:
#                team_name    tid         competition_name  type  game_count
# 0    Toronto Maple Leafs      1  2010 NHL Regular Season     2          82
# 1    Toronto Maple Leafs      1  2011 NHL Regular Season     2          40
# 2    Toronto Maple Leafs      1         2012 NHL Playoff     3           7
# 3    Toronto Maple Leafs      1  2012 NHL Regular Season     2          46
# 4    Toronto Maple Leafs      1  2013 NHL Regular Season     2          79
# ..                   ...    ...                      ...   ...         ...
# 364  Carolina Hurricanes     66  2014 NHL Regular Season     2          82
# 365  Carolina Hurricanes     66  2015 NHL Regular Season     2          81
# 366  Carolina Hurricanes     66  2016 NHL Regular Season     2          82
# 367  Carolina Hurricanes     66  2017 NHL Regular Season     2          80
# 368    Atlanta Thrashers  11366  2010 NHL Regular Season     2          79
#
# [369 rows x 5 columns]

# %%
#Merging dataframes.
#(i) Merging the “NHL_Game_Count” df into the “NHL_Team_Stats” df by “tid”, “competition_name”, and “type”. 
#Continue to name the merged df “NHL_Team_Stats”.

NHL_Team_Stats = pd.merge(NHL_Game_Count, NHL_Team_Stats, on=['tid','competition_name','type','team_name'])
display(NHL_Team_Stats)
# Out:
#                team_name    tid         competition_name  type  game_count  \
# 0    Toronto Maple Leafs      1  2010 NHL Regular Season     2          82
# 1    Toronto Maple Leafs      1  2011 NHL Regular Season     2          40
# 2    Toronto Maple Leafs      1         2012 NHL Playoff     3           7
# 3    Toronto Maple Leafs      1  2012 NHL Regular Season     2          46
# 4    Toronto Maple Leafs      1  2013 NHL Regular Season     2          79
# ..                   ...    ...                      ...   ...         ...
# 364  Carolina Hurricanes     66  2014 NHL Regular Season     2          82
# 365  Carolina Hurricanes     66  2015 NHL Regular Season     2          81
# 366  Carolina Hurricanes     66  2016 NHL Regular Season     2          82
# 367  Carolina Hurricanes     66  2017 NHL Regular Season     2          80
# 368    Atlanta Thrashers  11366  2010 NHL Regular Season     2          79
#
#       win  goals_for  goals_against
# ...

# %%
#(ii) Merging the “NHL_Team” df into the “NHL_Team_Stats” df by “tid”. 
#Continue to name the merged dataframe “NHL_Team_Stats”.

NHL_Team_Stats = pd.merge(NHL_Team,NHL_Team_Stats, on=['tid', 'team_name'])
display(NHL_Team_Stats)
# Out:
#        tid            team_name tricode         competition_name  type  \
# 0        1  Toronto Maple Leafs     TOR  2010 NHL Regular Season     2
# 1        1  Toronto Maple Leafs     TOR  2011 NHL Regular Season     2
# 2        1  Toronto Maple Leafs     TOR         2012 NHL Playoff     3
# 3        1  Toronto Maple Leafs     TOR  2012 NHL Regular Season     2
# 4        1  Toronto Maple Leafs     TOR  2013 NHL Regular Season     2
# ..     ...                  ...     ...                      ...   ...
# 364     66  Carolina Hurricanes     CAR  2014 NHL Regular Season     2
# 365     66  Carolina Hurricanes     CAR  2015 NHL Regular Season     2
# 366     66  Carolina Hurricanes     CAR  2016 NHL Regular Season     2
# 367     66  Carolina Hurricanes     CAR  2017 NHL Regular Season     2
# 368  11366    Atlanta Thrashers     ATL  2010 NHL Regular Season     2
#
#      game_count   win  goals_for  goals_against
# 0            82  36.0      223.0          259.0
# ...

# %%
#Import NHL PPPK Data and Display Head
NHL_PPPK=pd.read_csv("Assignment Data/Week 2/pp.pk.ppgf.csv")
NHL_PPPK.head()
# Out:
#   tricode   pp   pk  ppgf  competition_name
# 0     ANA   35   27   9.0  2010 NHL Playoff
# 1     BOS  126  116  22.0  2010 NHL Playoff
# 2     BUF   48   46  13.0  2010 NHL Playoff
# 3     CHI   27   39   6.0  2010 NHL Playoff
# 4     DET   59   55   6.0  2010 NHL Playoff

# %%
#Merging the “NHL_PPPK” dataframe into the “NHL_Team_Stats” dataframe by “tricode” and “competition_name”.
NHL_Team_Stats = pd.merge(NHL_Team_Stats, NHL_PPPK, on=['tricode','competition_name'])
display(NHL_Team_Stats)
# Out:
#        tid            team_name tricode         competition_name  type  \
# 0        1  Toronto Maple Leafs     TOR  2010 NHL Regular Season     2
# 1        1  Toronto Maple Leafs     TOR  2011 NHL Regular Season     2
# 2        1  Toronto Maple Leafs     TOR         2012 NHL Playoff     3
# 3        1  Toronto Maple Leafs     TOR  2012 NHL Regular Season     2
# 4        1  Toronto Maple Leafs     TOR  2013 NHL Regular Season     2
# ..     ...                  ...     ...                      ...   ...
# 364     66  Carolina Hurricanes     CAR  2014 NHL Regular Season     2
# 365     66  Carolina Hurricanes     CAR  2015 NHL Regular Season     2
# 366     66  Carolina Hurricanes     CAR  2016 NHL Regular Season     2
# 367     66  Carolina Hurricanes     CAR  2017 NHL Regular Season     2
# 368  11366    Atlanta Thrashers     ATL  2010 NHL Regular Season     2
#
#      game_count   win  goals_for  goals_against   pp   pk  ppgf
# ...

# %%
#Creating new variables in the “NHL_Team_Stats” dataframe.
#(i)Winning percentage (“win_pct”)=”win”/ total number of games played
#(ii)Average goals for per game (“avg_gf”)=total number of goals for / total number of games played     
#(iii)Average goals against per game (“avg_ga”)=total number of goals against / total number of games played

NHL_Team_Stats['win_pct']=NHL_Team_Stats['win']/NHL_Team_Stats['game_count']
NHL_Team_Stats['avg_gf']=NHL_Team_Stats['goals_for']/NHL_Team_Stats['game_count']
NHL_Team_Stats['avg_ga']=NHL_Team_Stats['goals_against']/NHL_Team_Stats['game_count']
display(NHL_Team_Stats)
# Out:
#        tid            team_name tricode         competition_name  type  \
# 0        1  Toronto Maple Leafs     TOR  2010 NHL Regular Season     2
# 1        1  Toronto Maple Leafs     TOR  2011 NHL Regular Season     2
# 2        1  Toronto Maple Leafs     TOR         2012 NHL Playoff     3
# 3        1  Toronto Maple Leafs     TOR  2012 NHL Regular Season     2
# 4        1  Toronto Maple Leafs     TOR  2013 NHL Regular Season     2
# ..     ...                  ...     ...                      ...   ...
# 364     66  Carolina Hurricanes     CAR  2014 NHL Regular Season     2
# 365     66  Carolina Hurricanes     CAR  2015 NHL Regular Season     2
# 366     66  Carolina Hurricanes     CAR  2016 NHL Regular Season     2
# 367     66  Carolina Hurricanes     CAR  2017 NHL Regular Season     2
# 368  11366    Atlanta Thrashers     ATL  2010 NHL Regular Season     2
#
#      game_count   win  goals_for  goals_against   pp   pk  ppgf   win_pct  \
# ...

# %%
#In the “NHL_Competition” dataframe, the variable “type” indicates the type of competition:
#type=2 – regular season. Create a dataframe that contains team statistics for games only during regular seasons.
#Name this dataframe “NHL_Team_R_Stats”. 

NHL_Team_R_Stats = NHL_Team_Stats[NHL_Team_Stats['type']==2]
display(NHL_Team_R_Stats)
# Out:
#        tid            team_name tricode         competition_name  type  \
# 0        1  Toronto Maple Leafs     TOR  2010 NHL Regular Season     2
# 1        1  Toronto Maple Leafs     TOR  2011 NHL Regular Season     2
# 3        1  Toronto Maple Leafs     TOR  2012 NHL Regular Season     2
# 4        1  Toronto Maple Leafs     TOR  2013 NHL Regular Season     2
# 5        1  Toronto Maple Leafs     TOR  2014 NHL Regular Season     2
# ..     ...                  ...     ...                      ...   ...
# 364     66  Carolina Hurricanes     CAR  2014 NHL Regular Season     2
# 365     66  Carolina Hurricanes     CAR  2015 NHL Regular Season     2
# 366     66  Carolina Hurricanes     CAR  2016 NHL Regular Season     2
# 367     66  Carolina Hurricanes     CAR  2017 NHL Regular Season     2
# 368  11366    Atlanta Thrashers     ATL  2010 NHL Regular Season     2
#
#      game_count   win  goals_for  goals_against   pp   pk  ppgf   win_pct  \
# ...

# %% [markdown]
# ## Part 2 - Descriptive and Summary Analyses

# %%
#In the “NHL_Game” dataframe, calculate summary statistics for the  “goals_for” variable; 
NHL_Game['goals_for'].describe()
# Out:
# count    18506.000000
# mean         2.825894
# std          1.654729
# min          0.000000
# 25%          2.000000
# 50%          3.000000
# 75%          4.000000
# max         10.000000
# Name: goals_for, dtype: float64

# %%
#calculate summary statistics for the “goals_against” variable based on whether it is home or away game.
NHL_Game.groupby(['home_away'])['goals_against'].describe()
# Out:
#             count      mean       std  min  25%  50%  75%   max
# home_away
# away       9253.0  2.961958  1.688463  0.0  2.0  3.0  4.0  10.0
# home       9253.0  2.689830  1.608916  0.0  1.0  3.0  4.0  10.0

# %%
#Create a histogram of the “goals_against” variable by whether the game is home or away 
#(i)Make the color of the histogram green
#(ii)Set the number of bins to be 20
#(iii)Make sure the two sub-histograms share the same ranges for the x-axis and y-axis.

NHL_Game.hist(by='home_away',column='goals_against',color='green',bins=20, sharex=True,sharey=True)
plt.show()

# %% [markdown]
# ## Part 3 - Correlation Analyses

# %%
#In the “NHL_Team_R_Stats” dataframe, make a scatter plot to depict the relationship between the total number of goals for and the winning percentage. 
#(i)Plot the total number of goals for on the x-axis and winning percentage on the y-axis.
#(ii)Add a regression line to the scatter plot.
#(iii)Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11.
#(iv)Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.

sns.regplot(x='goals_for',y='win_pct', data=NHL_Team_R_Stats, marker='.')
plt.xlabel('Total Goals for')
plt.ylabel('Winning %')
plt.title('Relationship Between Goals for and Winning %', fontsize=11)
plt.show()

# %%
#In the “NHL_Team_R_Stats” dataframe, calculate the correlation coefficient between total number of 
#goals for and winning percentage.

NHL_Team_R_Stats['goals_for'].corr(NHL_Team_R_Stats['win_pct'])
# Out:
# 0.31566456280848143

# %%
#Create a scatter plot of the total number of goals for and winning percentage similar to step 1 for 
#regular season games. In this graph, group observations by “competition_name”.
#(i)Plot the total number of goals for on the x-axis and winning percentage on the y-axis.
#(ii)Add a regression line to the scatter plot.
#(iii)Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11.
#(iv)Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.

sns.lmplot(x='goals_for',y='win_pct', hue='competition_name', data=NHL_Team_Stats)
plt.title('Relationship between Goals for and Winning Percentage', fontsize=11)
plt.xlabel('Total Goals for')
plt.ylabel('Winning Percentage')
plt.show()

# %%
#For the “NHL_Team_R_Stats” dataframe, delete observations of 2011 and 2012 seasons. 
#Continue to name the dataframe “NHL_Team_R_Stats”.

NHL_Team_R_Stats = NHL_Team_R_Stats[
    (NHL_Team_R_Stats.competition_name != '2011 NHL Regular Season') &
    (NHL_Team_R_Stats.competition_name != '2011 NHL Playoff') &
    (NHL_Team_R_Stats.competition_name != '2012 NHL Regular Season') &
    (NHL_Team_R_Stats.competition_name != '2012 NHL Playoff')]
display(NHL_Team_R_Stats)
# Out:
#        tid            team_name tricode         competition_name  type  \
# 0        1  Toronto Maple Leafs     TOR  2010 NHL Regular Season     2
# 4        1  Toronto Maple Leafs     TOR  2013 NHL Regular Season     2
# 5        1  Toronto Maple Leafs     TOR  2014 NHL Regular Season     2
# 6        1  Toronto Maple Leafs     TOR  2015 NHL Regular Season     2
# 8        1  Toronto Maple Leafs     TOR  2016 NHL Regular Season     2
# ..     ...                  ...     ...                      ...   ...
# 364     66  Carolina Hurricanes     CAR  2014 NHL Regular Season     2
# 365     66  Carolina Hurricanes     CAR  2015 NHL Regular Season     2
# 366     66  Carolina Hurricanes     CAR  2016 NHL Regular Season     2
# 367     66  Carolina Hurricanes     CAR  2017 NHL Regular Season     2
# 368  11366    Atlanta Thrashers     ATL  2010 NHL Regular Season     2
#
#      game_count   win  goals_for  goals_against   pp   pk  ppgf   win_pct  \
# ...

# %%
#In the new “NHL_Team_R_Stats” dataframe, create a scatter plot of total number of goals for and 
#winning percentage.
#(i)Plot the total number of goals for on the x-axis and winning percentage on the y-axis.
#(ii)Add a regression line to the scatter plot.
#(iii)Make the title of the graph “Relationship between Goals for and Winning Percentage” and make the font size 11.
#(iv)Label the x-axis “Total Goals for” and label the y-axis “Winning Percentage”.

sns.regplot(x='goals_for',y='win_pct',data=NHL_Team_R_Stats)
plt.title('Relationship Between Goals For and Winning Percentage', fontsize=11)
plt.ylabel('Winning Percentage')
plt.xlabel('Total Goals For')
plt.show()

# %%
#Calculate the correlation coefficient between total number of goals for and winning percentage 
#in the updated “NHL_Team_R_Stats” dataframe.

NHL_Team_R_Stats['goals_for'].corr(NHL_Team_R_Stats['win_pct'])
# Out:
# 0.7706255321801442

# %% [markdown]
# ## Uncomment this Section once your assignment is complete

# %%
#Save Dataframes as .csv files
#NHL_Game.to_csv("NHL_Game2.csv", index=False)
#NHL_Team_Stats.to_csv("NHL_Team_Stats.csv", index=False)
#NHL_Team_R_Stats.to_csv("NHL_Team_R_Stats.csv", index=False)
